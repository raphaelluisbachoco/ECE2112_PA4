# %% [markdown]
# Created By : Raphael Luis L. Bachoco

# %% [markdown]
# Section: 2ECE-D

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
board2 = pd.read_excel('board2.xlsx')

# %% [markdown]
# # Problem A

# %%
board2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %%
board2['average'] = (board2['Math'] + board2['Electronics'] + board2['GEAS'] + board2['Communication'])/4
board2['average']
# Out:
# 0     75.00
# 1     67.25
# 2     72.75
# 3     70.50
# 4     69.00
# 5     75.50
# 6     58.50
# 7     61.75
# 8     47.75
# 9     67.25
# 10    54.75
# 11    76.00
# 12    62.25
# 13    80.50
# 14    59.00
# 15    77.25
# 16    70.50
# 17    63.50
# 18    73.00
# 19    66.50
# 20    68.50
# 21    62.50
# 22    68.75
# 23    57.75
# 24    75.25
# 25    65.75
# 26    60.75
# 27    67.75
# 28    63.50
# 29    68.00
# Name: average, dtype: float64

# %%
VisComm = board2.loc[(board2['Hometown'] == 'Visayas') & (board2['Track'] == 'Communication'), ['Name', 'Gender', 'Math', 'Electronics', 'average']]
VisComm
# Out:
#    Name  Gender  Math  Electronics  average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %% [markdown]
# # Problem B

# %%
board2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication  average
# 0              78    75.00
# 1              52    67.25
# 2              57    72.75
# 3              68    70.50
# 4              88    69.00
# 5              83    75.50
# 6              48    58.50
# 7              53    61.75
# 8              42    47.75
# 9              44    67.25
# 10             67    54.75
# 11             64    76.00
# 12             43    62.25
# 13             73    80.50
# 14             86    59.00
# 15             81    77.25
# 16             45    70.50
# 17             52    63.50
# 18             71    73.00
# 19             85    66.50
# 20             72    68.50
# 21             58    62.50
# 22             47    68.75
# 23             41    57.75
# 24             42    75.25
# 25             62    65.75
# 26             86    60.75
# 27             53    67.75
# 28             62    63.50
# 29             56    68.00

# %%
BeforeavgVisFemale = board2.loc[(board2['Hometown'] == 'Visayas') & (board2['Gender'] == 'Female'), ['Name', 'Track', 'Math', 'Electronics', 'average']]
BeforeavgVisFemale
# Out:
#    Name             Track  Math  Electronics  average
# 5    S6  Microelectronics    88           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    83           51    68.50
# 21  S22     Communication    64           39    62.50
# 23  S24  Microelectronics    85           45    57.75
# 25  S26   Instrumentation    71           47    65.75

# %%
VisFemale = BeforeavgVisFemale.loc[(board2['average'] >= 60)]
VisFemale
# Out:
#    Name             Track  Math  Electronics  average
# 5    S6  Microelectronics    88           45    75.50
# 20  S21  Microelectronics    83           51    68.50
# 21  S22     Communication    64           39    62.50
# 25  S26   Instrumentation    71           47    65.75

# %% [markdown]
# # Problem C

# %%
board2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication  average
# 0              78    75.00
# 1              52    67.25
# 2              57    72.75
# 3              68    70.50
# 4              88    69.00
# 5              83    75.50
# 6              48    58.50
# 7              53    61.75
# 8              42    47.75
# 9              44    67.25
# 10             67    54.75
# 11             64    76.00
# 12             43    62.25
# 13             73    80.50
# 14             86    59.00
# 15             81    77.25
# 16             45    70.50
# 17             52    63.50
# 18             71    73.00
# 19             85    66.50
# 20             72    68.50
# 21             58    62.50
# 22             47    68.75
# 23             41    57.75
# 24             42    75.25
# 25             62    65.75
# 26             86    60.75
# 27             53    67.75
# 28             62    63.50
# 29             56    68.00

# %%
track = board2.pivot_table(index='Track', values='average').reset_index()
gender = board2.pivot_table(index='Gender', values='average').reset_index()
hometown = board2.pivot_table(index='Hometown', values='average').reset_index()

# %%
track
# Out:
#               Track  average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500

# %%
gender
# Out:
#    Gender    average
# 0  Female  66.616667
# 1    Male  67.183333

# %%
hometown
# Out:
#    Hometown    average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %%
TopTrack = track.loc[track['average'].idxmax()]
TopGender = gender.loc[gender['average'].idxmax()]
TopHometown = hometown.loc[hometown['average'].idxmax()]

# %%
TopTrack
# Out:
# Track      Communication
# average           67.975
# Name: 0, dtype: object

# %%
TopGender
# Out:
# Gender          Male
# average    67.183333
# Name: 1, dtype: object

# %%
TopHometown
# Out:
# Hometown        Luzon
# average     68.083333
# Name: 0, dtype: object

# %%
graph, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))
axes[0].bar(track['Track'], track['average'], color='red')
axes[0].set(title='Mean average by Track', xlabel='Track', ylabel='Mean average')

axes[1].bar(gender['Gender'], gender['average'], color='green')
axes[1].set(title='Mean average by Gender', xlabel='Gender', ylabel='Mean average')

axes[2].bar(hometown['Hometown'], hometown['average'], color='blue')
axes[2].set(title='Mean average by Hometown', xlabel='Hometown', ylabel='Mean average')

graph.text(0.35,0.02, 'Summary of Results:')
graph.text(0.35,-0.01, 'For Mean average by Track, Communications leads with highest mean average of (67.183333)')
graph.text(0.35,-0.04, 'For Mean average by Gender, Male leads with highest mean average of (67.183333)')
graph.text(0.35,-0.07, 'For Mean average by Hometown, Luzon leads with the highest mean average of (68.083333) ')
# Out:
# Text(0.35, -0.07, 'For Mean average by Hometown, Luzon leads with the highest mean average of (68.083333) ')
